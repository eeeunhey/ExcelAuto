# %%
pip install xlwings
# Out:
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.6 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 8.2 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    --------- ------------------------------ 2.4/9.5 MB 11.1 MB/s eta 0:00:01
#    -------------------- ------------------- 5.0/9.5 MB 11.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.4/9.5 MB 13.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 11.8 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
# ...

# %%
import xlwings as xw

# 엑셀 앱 만들기
app = xw.App(add_book=False)
